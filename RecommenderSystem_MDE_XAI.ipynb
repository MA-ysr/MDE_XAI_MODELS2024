# %% [markdown]
# <a href="https://colab.research.google.com/github/MA-ysr/MDE_XAI_MODELS2024/blob/main/RecommenderSystem_MDE_XAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install packages**

# %%
# !pip install pyecore
# Out:
# Collecting pyecore
#   Downloading pyecore-0.15.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 775.6 kB/s eta 0:00:00
# Collecting ordered-set>=4.0.1 (from pyecore)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting restrictedpython>=5.3,>=6.1 (from pyecore)
#   Downloading RestrictedPython-7.1-py3-none-any.whl (26 kB)
# Collecting future-fstrings (from pyecore)
#   Downloading future_fstrings-1.2.0-py2.py3-none-any.whl (6.1 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pyecore) (4.9.4)
# Installing collected packages: restrictedpython, ordered-set, future-fstrings, pyecore
# Successfully installed future-fstrings-1.2.0 ordered-set-4.1.0 pyecore-0.15.1 restrictedpython-7.1

# %%
# !pip install pyecoregen
# Out:
# Collecting pyecoregen
#   Downloading pyecoregen-0.5.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: pyecore in /usr/local/lib/python3.10/dist-packages (from pyecoregen) (0.15.1)
# Collecting pymultigen (from pyecoregen)
#   Downloading pymultigen-0.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyecoregen) (3.1.4)
# Collecting autopep8 (from pyecoregen)
#   Downloading autopep8-2.3.1-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 735.4 kB/s eta 0:00:00
# Collecting pycodestyle>=2.12.0 (from autopep8->pyecoregen)
#   Downloading pycodestyle-2.12.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8->pyecoregen) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyecoregen) (2.1.5)
# Requirement already satisfied: ordered-set>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from pyecore->pyecoregen) (4.1.0)
# Requirement already satisfied: restrictedpython>=5.3,>=6.1 in /usr/local/lib/python3.10/dist-packages (from pyecore->pyecoregen) (7.1)
# Requirement already satisfied: future-fstrings in /usr/local/lib/python3.10/dist-packages (from pyecore->pyecoregen) (1.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pyecore->pyecoregen) (4.9.4)
# Installing collected packages: pymultigen, pycodestyle, autopep8, pyecoregen
# Successfully installed autopep8-2.3.1 pycodestyle-2.12.0 pyecoregen-0.5.1 pymultigen-0.2.0

# %% [markdown]
# **Import packages**

# %%
import numpy as np
from sklearn.decomposition import NMF
from sklearn.preprocessing import MinMaxScaler
from pyecore.resources import ResourceSet, URI
from pyecore.ecore import EPackage
from pyecore.resources.xmi import XMIResource
from pyecore.ecore import EFloat
from functools import partial

# %% [markdown]
# **Load the metamodel & Generate classes**

# %%
# Load the metamodel
rset = ResourceSet()
resource = rset.get_resource(URI('content_recommendation.ecore'))
mm_root = resource.contents[0]
rset.metamodel_registry[mm_root.nsURI] = mm_root

# Generate Python classes from the metamodel
from pyecoregen.ecore import EcoreGenerator
generator = EcoreGenerator()
generator.generate(mm_root, 'content_recommendation_mm')

# %% [markdown]
# **Import generated classes**

# %%
from content_recommendation_mm.airecommendationsystem import (  # Import from the single file
    User, Content, Rating, Recommendation, Explanation, ExplanationFactor,
    AIRecommendationEngine, AIModel, AIModelTracer, PredictionTrace, ExplanationType,
    getEClassifier, eClassifiers
)
import content_recommendation_mm.airecommendationsystem as mm  # Import the module itself

# %% [markdown]
# **Add method to calculate feature importance and trace prediction**

# %%
def trace_prediction(self, user, content, recommendation):
    trace = mm.PredictionTrace()
    trace.userId = user.id
    trace.contentId = content.id
    trace.predictedRating = recommendation.predictedRating
    trace.explanation = recommendation.explanation
    self.traces.append(trace)
    return trace

mm.AIModelTracer.tracePrediction = trace_prediction

# %% [markdown]
# **AI-based Recommendation Engine**

# %%
class OriginalAIModel(AIModel):
    def __init__(self):
        super().__init__()
        self.isExplainable = False
        self.model = NMF(n_components=2, init='random', random_state=42)
        self.user_factors = None
        self.item_factors = None
        self.scaler = MinMaxScaler(feature_range=(1.0, 5.0))  # Use float values

    def fit(self, rating_matrix):
        self.user_factors = self.model.fit_transform(rating_matrix)
        self.item_factors = self.model.components_.T

        # Fit the scaler on all predicted ratings
        all_predictions = np.dot(self.user_factors, self.item_factors.T).flatten()
        self.scaler.fit(all_predictions.reshape(-1, 1))

    def predict(self, user_idx, content_idx):
        user_vector = self.user_factors[user_idx]
        content_vector = self.item_factors[content_idx]
        predicted_rating = float(np.dot(user_vector, content_vector))  # Convert to float
        return float(self.scaler.transform([[predicted_rating]])[0][0])  # Convert to float

    def extractFactors(self, user_idx, content_idx):
        return self.user_factors[user_idx].astype(float), self.item_factors[content_idx].astype(float)

class ExplainableAIModel(AIModel):
    def __init__(self, original_model):
        super().__init__()
        self.isExplainable = True
        self.original_model = original_model

    def fit(self, rating_matrix):
        self.original_model.fit(rating_matrix)

    def predict(self, user_idx, content_idx):
        return self.original_model.predict(user_idx, content_idx)

    def extractFactors(self, user_idx, content_idx):
        return self.original_model.extractFactors(user_idx, content_idx)

    def predictAndExplain(self, user_idx, content_idx):
        predicted_rating = self.predict(user_idx, content_idx)
        user_vector, content_vector = self.extractFactors(user_idx, content_idx)

        explanation = mm.Explanation()
        explanation.type = mm.ExplanationType.FACTOR_BASED
        explanation.content = f"The predicted rating of {predicted_rating:.2f} is based on the following factors:"

        factor_values = [abs(float(u*c)) for u, c in zip(user_vector, content_vector)]
        total_importance = sum(factor_values)

        for i, (user_factor, content_factor) in enumerate(zip(user_vector, content_vector)):
            factor = ExplanationFactorImpl()  # Use the custom implementation
            factor.name = f"Latent Factor {i+1}"
            factor.value = float(user_factor * content_factor)
            factor.importance = float(abs(factor.value) / total_importance) if total_importance != 0 else 0.0
            explanation.factors.append(factor)

        return predicted_rating, explanation

def transform_model(original_model):
    return ExplainableAIModel(original_model)

class RealTimeExplainer:
    def __init__(self, ai_model):
        self.ai_model = ai_model
        self.explanation_history = []

    def explain_in_realtime(self, user_idx, content_idx):
        predicted_rating, explanation = self.ai_model.predictAndExplain(user_idx, content_idx)
        self.explanation_history.append(explanation)
        return predicted_rating, explanation

class ExplanationFactorImpl(mm.ExplanationFactor):
    def __init__(self):
        super().__init__()
        self._importance = 0.0

    @property
    def importance(self):
        return self._importance

    @importance.setter
    def importance(self, value):
        self._importance = float(value)  # Ensure the value is always converted to float

# Replace the original ExplanationFactor with our implementation
mm.ExplanationFactor = ExplanationFactorImpl

class AIRecommendationEngineImpl(AIRecommendationEngine):
    def __init__(self):
        super().__init__()
        self.original_model = OriginalAIModel()
        self.explainable_model = None
        self.real_time_explainer = None
        self.tracer = mm.AIModelTracer()
        self.user_id_map = {}
        self.content_id_map = {}

    def trainModel(self):
        self.user_id_map = {user.id: i for i, user in enumerate(self.users)}
        self.content_id_map = {content.id: i for i, content in enumerate(self.contentCatalog)}

        rating_matrix = np.zeros((len(self.users), len(self.contentCatalog)))
        for rating in self.ratings:
            user_idx = self.user_id_map[rating.user.id]
            content_idx = self.content_id_map[rating.content.id]
            rating_matrix[user_idx, content_idx] = rating.score

        rating_matrix += 0.01  # Add small constant to avoid zero entries
        self.original_model.fit(rating_matrix)
        self.explainable_model = transform_model(self.original_model)
        self.real_time_explainer = RealTimeExplainer(self.explainable_model)

    def predictAndExplain(self, user, content):
        user_idx = self.user_id_map[user.id]
        content_idx = self.content_id_map[content.id]

        predicted_rating, explanation = self.real_time_explainer.explain_in_realtime(user_idx, content_idx)

        recommendation = mm.Recommendation()
        recommendation.user = user
        recommendation.recommendedContent = content
        recommendation.predictedRating = float(predicted_rating)
        recommendation.explanation = explanation  # Ensure this line is present

        self.tracer.tracePrediction(user, content, recommendation)

        return recommendation, explanation

    def add_user(self, id, name):
        user = mm.User()
        user.id = id
        user.name = name
        self.users.append(user)
        return user

    def add_content(self, id, title, genre):
        content = mm.Content()
        content.id = id
        content.title = title
        content.genre = genre
        self.contentCatalog.append(content)
        return content

    def add_rating(self, user, content, score):
        rating = mm.Rating()
        rating.user = user
        rating.content = content
        rating.score = float(score)
        self.ratings.append(rating)
        return rating

# %% [markdown]
# **Create sample data**

# %%
# Create and populate the AI Recommendation Engine
engine = AIRecommendationEngineImpl()

# Add users
for i in range(1, 6):
    engine.add_user(i, f"User{i}")

# Add content
content_data = [
    (1, "Action Movie 1", "Action"),
    (2, "Comedy Movie 1", "Comedy"),
    (3, "Drama Movie 1", "Drama"),
    (4, "Action Movie 2", "Action"),
    (5, "Comedy Movie 2", "Comedy")
]

for id, title, genre in content_data:
    engine.add_content(id, title, genre)

# Add ratings
for user in engine.users:
    for content in engine.contentCatalog:
        if np.random.random() > 0.2:  # 80% chance of rating each item
            score = np.random.uniform(1, 5)  # Generate a float between 1 and 5
            engine.add_rating(user, content, score)

print(f"Created {len(engine.ratings)} ratings")
# Out:
# Created 22 ratings

# %% [markdown]
# **Explanation format**

# %%
def generate_user_friendly_explanation(user, content, predicted_rating, explanation):
    #print(f"Debug: Explanation for {content.title} - {explanation}")  # Debug print
    if explanation is None or not explanation.factors:
        return f"We predict you'll rate '{content.title}' {predicted_rating:.1f} out of 5 stars, but we don't have enough information to explain why."

    non_zero_factors = [f for f in explanation.factors if f.value != 0]

    if len(non_zero_factors) == 0:
        return f"We predict you'll rate '{content.title}' {predicted_rating:.1f} out of 5 stars, but we can't determine the specific reasons."

    explanation_text = f"We predict you'll rate '{content.title}' {predicted_rating:.1f} out of 5 stars.\n"

    if len(non_zero_factors) == 1:
        factor = non_zero_factors[0]
        if factor.name == "Latent Factor 1":
            explanation_text += f"This is mainly because it seems to match your general movie preferences (Impact: {factor.importance:.0%})."
        else:
            explanation_text += f"This is mainly because it's similar to other movies you've enjoyed (Impact: {factor.importance:.0%})."
    else:
        explanation_text += "This is based on a combination of factors:\n"
        for factor in non_zero_factors:
            if factor.name == "Latent Factor 1":
                explanation_text += f"- It matches your general movie preferences (Impact: {factor.importance:.0%})\n"
            else:
                explanation_text += f"- It's similar to other movies you've enjoyed (Impact: {factor.importance:.0%})\n"

    return explanation_text

# %% [markdown]
# **Training the model and generate  explanations**

# %%
# Train the model
engine.trainModel()

# Generate and print recommendations with explanations for each user
for user in engine.users:
    print(f"\nRecommendations for {user.name}:")
    for content in engine.contentCatalog:
        recommendation, explanation = engine.predictAndExplain(user, content)
        user_friendly_explanation = generate_user_friendly_explanation(user, content, recommendation.predictedRating, explanation)
        print(user_friendly_explanation)

# Print tracing information
print("\nPrediction Traces:")
for trace in engine.tracer.traces:
    print(f"User {trace.userId} - Content {trace.contentId}: Predicted Rating {trace.predictedRating:.2f}")
    if trace.explanation and trace.explanation.factors:
        print(f"  Explanation: {trace.explanation.content}")
        for factor in trace.explanation.factors:
            print(f"    - {factor.name}: Value = {factor.value:.2f}, Importance = {factor.importance:.2f}")
    else:
        print("  No detailed explanation available.")
# Out:
# Recommendations for User1:
# We predict you'll rate 'Action Movie 1' 1.0 out of 5 stars, but we can't determine the specific reasons.
# We predict you'll rate 'Comedy Movie 1' 4.0 out of 5 stars.
# This is mainly because it's similar to other movies you've enjoyed (Impact: 100%).
# We predict you'll rate 'Drama Movie 1' 2.3 out of 5 stars.
# This is mainly because it's similar to other movies you've enjoyed (Impact: 100%).
# We predict you'll rate 'Action Movie 2' 3.2 out of 5 stars.
# This is mainly because it's similar to other movies you've enjoyed (Impact: 100%).
# We predict you'll rate 'Comedy Movie 2' 3.4 out of 5 stars.
# This is mainly because it's similar to other movies you've enjoyed (Impact: 100%).
#
# Recommendations for User2:
# We predict you'll rate 'Action Movie 1' 3.6 out of 5 stars.
# This is mainly because it seems to match your general movie preferences (Impact: 100%).
# We predict you'll rate 'Comedy Movie 1' 3.1 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 31%)
# - It's similar to other movies you've enjoyed (Impact: 69%)
#
# We predict you'll rate 'Drama Movie 1' 1.7 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 11%)
# - It's similar to other movies you've enjoyed (Impact: 89%)
#
# We predict you'll rate 'Action Movie 2' 3.6 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 60%)
# - It's similar to other movies you've enjoyed (Impact: 40%)
#
# We predict you'll rate 'Comedy Movie 2' 3.4 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 53%)
# - It's similar to other movies you've enjoyed (Impact: 47%)
#
#
# Recommendations for User3:
# We predict you'll rate 'Action Movie 1' 3.8 out of 5 stars.
# This is mainly because it seems to match your general movie preferences (Impact: 100%).
# We predict you'll rate 'Comedy Movie 1' 2.4 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 49%)
# - It's similar to other movies you've enjoyed (Impact: 51%)
#
# We predict you'll rate 'Drama Movie 1' 1.4 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 20%)
# - It's similar to other movies you've enjoyed (Impact: 80%)
#
# We predict you'll rate 'Action Movie 2' 3.3 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 76%)
# - It's similar to other movies you've enjoyed (Impact: 24%)
#
# We predict you'll rate 'Comedy Movie 2' 3.0 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 70%)
# - It's similar to other movies you've enjoyed (Impact: 30%)
#
#
# Recommendations for User4:
# We predict you'll rate 'Action Movie 1' 3.3 out of 5 stars.
# This is mainly because it seems to match your general movie preferences (Impact: 100%).
# We predict you'll rate 'Comedy Movie 1' 2.6 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 37%)
# - It's similar to other movies you've enjoyed (Impact: 63%)
#
# We predict you'll rate 'Drama Movie 1' 1.5 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 13%)
# - It's similar to other movies you've enjoyed (Impact: 87%)
#
# We predict you'll rate 'Action Movie 2' 3.1 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 66%)
# - It's similar to other movies you've enjoyed (Impact: 34%)
#
# We predict you'll rate 'Comedy Movie 2' 2.9 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 59%)
# - It's similar to other movies you've enjoyed (Impact: 41%)
#
#
# Recommendations for User5:
# We predict you'll rate 'Action Movie 1' 5.0 out of 5 stars.
# This is mainly because it seems to match your general movie preferences (Impact: 100%).
# We predict you'll rate 'Comedy Movie 1' 3.1 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 48%)
# - It's similar to other movies you've enjoyed (Impact: 52%)
#
# We predict you'll rate 'Drama Movie 1' 1.6 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 19%)
# - It's similar to other movies you've enjoyed (Impact: 81%)
#
# We predict you'll rate 'Action Movie 2' 4.3 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 75%)
# - It's similar to other movies you've enjoyed (Impact: 25%)
#
# We predict you'll rate 'Comedy Movie 2' 3.9 out of 5 stars.
# This is based on a combination of factors:
# - It matches your general movie preferences (Impact: 69%)
# - It's similar to other movies you've enjoyed (Impact: 31%)
#
#
# Prediction Traces:
# User 1 - Content 1: Predicted Rating 1.00
#   Explanation: The predicted rating of 1.00 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 1 - Content 2: Predicted Rating 4.04
#   Explanation: The predicted rating of 4.04 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 4.07, Importance = 1.00
# User 1 - Content 3: Predicted Rating 2.34
#   Explanation: The predicted rating of 2.34 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 1.79, Importance = 1.00
# User 1 - Content 4: Predicted Rating 3.25
#   Explanation: The predicted rating of 3.25 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 3.01, Importance = 1.00
# User 1 - Content 5: Predicted Rating 3.45
#   Explanation: The predicted rating of 3.45 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 3.28, Importance = 1.00
# User 2 - Content 1: Predicted Rating 3.60
#   Explanation: The predicted rating of 3.60 is based on the following factors:
#     - Latent Factor 1: Value = 3.48, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 2 - Content 2: Predicted Rating 3.08
#   Explanation: The predicted rating of 3.08 is based on the following factors:
#     - Latent Factor 1: Value = 0.87, Importance = 0.31
#     - Latent Factor 2: Value = 1.90, Importance = 0.69
# User 2 - Content 3: Predicted Rating 1.70
#   Explanation: The predicted rating of 1.70 is based on the following factors:
#     - Latent Factor 1: Value = 0.10, Importance = 0.11
#     - Latent Factor 2: Value = 0.84, Importance = 0.89
# User 2 - Content 4: Predicted Rating 3.65
#   Explanation: The predicted rating of 3.65 is based on the following factors:
#     - Latent Factor 1: Value = 2.14, Importance = 0.60
#     - Latent Factor 2: Value = 1.41, Importance = 0.40
# User 2 - Content 5: Predicted Rating 3.43
#   Explanation: The predicted rating of 3.43 is based on the following factors:
#     - Latent Factor 1: Value = 1.72, Importance = 0.53
#     - Latent Factor 2: Value = 1.53, Importance = 0.47
# User 3 - Content 1: Predicted Rating 3.80
#   Explanation: The predicted rating of 3.80 is based on the following factors:
#     - Latent Factor 1: Value = 3.74, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 3 - Content 2: Predicted Rating 2.44
#   Explanation: The predicted rating of 2.44 is based on the following factors:
#     - Latent Factor 1: Value = 0.94, Importance = 0.49
#     - Latent Factor 2: Value = 0.99, Importance = 0.51
# User 3 - Content 3: Predicted Rating 1.41
#   Explanation: The predicted rating of 1.41 is based on the following factors:
#     - Latent Factor 1: Value = 0.11, Importance = 0.20
#     - Latent Factor 2: Value = 0.44, Importance = 0.80
# User 3 - Content 4: Predicted Rating 3.27
#   Explanation: The predicted rating of 3.27 is based on the following factors:
#     - Latent Factor 1: Value = 2.30, Importance = 0.76
#     - Latent Factor 2: Value = 0.74, Importance = 0.24
# User 3 - Content 5: Predicted Rating 2.98
#   Explanation: The predicted rating of 2.98 is based on the following factors:
#     - Latent Factor 1: Value = 1.85, Importance = 0.70
#     - Latent Factor 2: Value = 0.80, Importance = 0.30
# User 4 - Content 1: Predicted Rating 3.28
#   Explanation: The predicted rating of 3.28 is based on the following factors:
#     - Latent Factor 1: Value = 3.06, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 4 - Content 2: Predicted Rating 2.56
#   Explanation: The predicted rating of 2.56 is based on the following factors:
#     - Latent Factor 1: Value = 0.77, Importance = 0.37
#     - Latent Factor 2: Value = 1.32, Importance = 0.63
# User 4 - Content 3: Predicted Rating 1.50
#   Explanation: The predicted rating of 1.50 is based on the following factors:
#     - Latent Factor 1: Value = 0.09, Importance = 0.13
#     - Latent Factor 2: Value = 0.58, Importance = 0.87
# User 4 - Content 4: Predicted Rating 3.13
#   Explanation: The predicted rating of 3.13 is based on the following factors:
#     - Latent Factor 1: Value = 1.87, Importance = 0.66
#     - Latent Factor 2: Value = 0.98, Importance = 0.34
# User 4 - Content 5: Predicted Rating 2.92
#   Explanation: The predicted rating of 2.92 is based on the following factors:
#     - Latent Factor 1: Value = 1.51, Importance = 0.59
#     - Latent Factor 2: Value = 1.07, Importance = 0.41
# User 5 - Content 1: Predicted Rating 5.00
#   Explanation: The predicted rating of 5.00 is based on the following factors:
#     - Latent Factor 1: Value = 5.35, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 5 - Content 2: Predicted Rating 3.11
#   Explanation: The predicted rating of 3.11 is based on the following factors:
#     - Latent Factor 1: Value = 1.34, Importance = 0.48
#     - Latent Factor 2: Value = 1.48, Importance = 0.52
# User 5 - Content 3: Predicted Rating 1.60
#   Explanation: The predicted rating of 1.60 is based on the following factors:
#     - Latent Factor 1: Value = 0.15, Importance = 0.19
#     - Latent Factor 2: Value = 0.65, Importance = 0.81
# User 5 - Content 4: Predicted Rating 4.27
#   Explanation: The predicted rating of 4.27 is based on the following factors:
#     - Latent Factor 1: Value = 3.28, Importance = 0.75
#     - Latent Factor 2: Value = 1.10, Importance = 0.25
# User 5 - Content 5: Predicted Rating 3.87
#   Explanation: The predicted rating of 3.87 is based on the following factors:
#     - Latent Factor 1: Value = 2.64, Importance = 0.69
#     - Latent Factor 2: Value = 1.19, Importance = 0.31
# User 1 - Content 1: Predicted Rating 1.00
#   Explanation: The predicted rating of 1.00 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 1 - Content 2: Predicted Rating 4.04
#   Explanation: The predicted rating of 4.04 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 4.07, Importance = 1.00
# User 1 - Content 3: Predicted Rating 2.34
#   Explanation: The predicted rating of 2.34 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 1.79, Importance = 1.00
# User 1 - Content 4: Predicted Rating 3.25
#   Explanation: The predicted rating of 3.25 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 3.01, Importance = 1.00
# User 1 - Content 5: Predicted Rating 3.45
#   Explanation: The predicted rating of 3.45 is based on the following factors:
#     - Latent Factor 1: Value = 0.00, Importance = 0.00
#     - Latent Factor 2: Value = 3.28, Importance = 1.00
# User 2 - Content 1: Predicted Rating 3.60
#   Explanation: The predicted rating of 3.60 is based on the following factors:
#     - Latent Factor 1: Value = 3.48, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 2 - Content 2: Predicted Rating 3.08
#   Explanation: The predicted rating of 3.08 is based on the following factors:
#     - Latent Factor 1: Value = 0.87, Importance = 0.31
#     - Latent Factor 2: Value = 1.90, Importance = 0.69
# User 2 - Content 3: Predicted Rating 1.70
#   Explanation: The predicted rating of 1.70 is based on the following factors:
#     - Latent Factor 1: Value = 0.10, Importance = 0.11
#     - Latent Factor 2: Value = 0.84, Importance = 0.89
# User 2 - Content 4: Predicted Rating 3.65
#   Explanation: The predicted rating of 3.65 is based on the following factors:
#     - Latent Factor 1: Value = 2.14, Importance = 0.60
#     - Latent Factor 2: Value = 1.41, Importance = 0.40
# User 2 - Content 5: Predicted Rating 3.43
#   Explanation: The predicted rating of 3.43 is based on the following factors:
#     - Latent Factor 1: Value = 1.72, Importance = 0.53
#     - Latent Factor 2: Value = 1.53, Importance = 0.47
# User 3 - Content 1: Predicted Rating 3.80
#   Explanation: The predicted rating of 3.80 is based on the following factors:
#     - Latent Factor 1: Value = 3.74, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 3 - Content 2: Predicted Rating 2.44
#   Explanation: The predicted rating of 2.44 is based on the following factors:
#     - Latent Factor 1: Value = 0.94, Importance = 0.49
#     - Latent Factor 2: Value = 0.99, Importance = 0.51
# User 3 - Content 3: Predicted Rating 1.41
#   Explanation: The predicted rating of 1.41 is based on the following factors:
#     - Latent Factor 1: Value = 0.11, Importance = 0.20
#     - Latent Factor 2: Value = 0.44, Importance = 0.80
# User 3 - Content 4: Predicted Rating 3.27
#   Explanation: The predicted rating of 3.27 is based on the following factors:
#     - Latent Factor 1: Value = 2.30, Importance = 0.76
#     - Latent Factor 2: Value = 0.74, Importance = 0.24
# User 3 - Content 5: Predicted Rating 2.98
#   Explanation: The predicted rating of 2.98 is based on the following factors:
#     - Latent Factor 1: Value = 1.85, Importance = 0.70
#     - Latent Factor 2: Value = 0.80, Importance = 0.30
# User 4 - Content 1: Predicted Rating 3.28
#   Explanation: The predicted rating of 3.28 is based on the following factors:
#     - Latent Factor 1: Value = 3.06, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 4 - Content 2: Predicted Rating 2.56
#   Explanation: The predicted rating of 2.56 is based on the following factors:
#     - Latent Factor 1: Value = 0.77, Importance = 0.37
#     - Latent Factor 2: Value = 1.32, Importance = 0.63
# User 4 - Content 3: Predicted Rating 1.50
#   Explanation: The predicted rating of 1.50 is based on the following factors:
#     - Latent Factor 1: Value = 0.09, Importance = 0.13
#     - Latent Factor 2: Value = 0.58, Importance = 0.87
# User 4 - Content 4: Predicted Rating 3.13
#   Explanation: The predicted rating of 3.13 is based on the following factors:
#     - Latent Factor 1: Value = 1.87, Importance = 0.66
#     - Latent Factor 2: Value = 0.98, Importance = 0.34
# User 4 - Content 5: Predicted Rating 2.92
#   Explanation: The predicted rating of 2.92 is based on the following factors:
#     - Latent Factor 1: Value = 1.51, Importance = 0.59
#     - Latent Factor 2: Value = 1.07, Importance = 0.41
# User 5 - Content 1: Predicted Rating 5.00
#   Explanation: The predicted rating of 5.00 is based on the following factors:
#     - Latent Factor 1: Value = 5.35, Importance = 1.00
#     - Latent Factor 2: Value = 0.00, Importance = 0.00
# User 5 - Content 2: Predicted Rating 3.11
#   Explanation: The predicted rating of 3.11 is based on the following factors:
#     - Latent Factor 1: Value = 1.34, Importance = 0.48
#     - Latent Factor 2: Value = 1.48, Importance = 0.52
# User 5 - Content 3: Predicted Rating 1.60
#   Explanation: The predicted rating of 1.60 is based on the following factors:
#     - Latent Factor 1: Value = 0.15, Importance = 0.19
#     - Latent Factor 2: Value = 0.65, Importance = 0.81
# User 5 - Content 4: Predicted Rating 4.27
#   Explanation: The predicted rating of 4.27 is based on the following factors:
#     - Latent Factor 1: Value = 3.28, Importance = 0.75
#     - Latent Factor 2: Value = 1.10, Importance = 0.25
# User 5 - Content 5: Predicted Rating 3.87
#   Explanation: The predicted rating of 3.87 is based on the following factors:
#     - Latent Factor 1: Value = 2.64, Importance = 0.69
#     - Latent Factor 2: Value = 1.19, Importance = 0.31
